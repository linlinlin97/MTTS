# %%
###### 
from _util import *
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"

import _experiment as _experiment
reload(_experiment)

# import shutil
# shutil.rmtree("res/0316") /
# shutil.rmtree("fig/0327")

# %%
N = 200
T = 200
K = 8
p = 15
sigma1_squares = [2, 1, 0.5, 0.25, 0.1]
sigmas = [1] # 0.5, 1, 2
sigma = 1
misspecifications = [("cos", [2/4, 2/4]), ("cos", [3/4, 1/4])]
for misspecification in misspecifications:
    for order in ["concurrent", "episodic"]:
        for sigma1_square in sigma1_squares:
            if misspecification == ("cos", [2/4, 2/4]):
                if order == "episodic":
                    if sigma1_square in [2, 1]:
                        continue
                else:
                    continue
            reload(_experiment)
            run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                             , order = order
                                             , sigma1_square = sigma1_square
                                             , is_Binary = False
                                             , sigma = sigma
                                             , save_prefix = "mis_{}_{}_{}".format(misspecification[0], misspecification[1][0], misspecification[1][1])
                                             , print_SNR = True
                                             , misspecification = misspecification
                                            )
#             r = run.run_multiple_parallel(96)
            r = run.run_multiple_parallel(100, 2)
            run.plot_regret(ci = None
                            , plot_mean = True
                           , skip_methods = ["OSFA"]
                            , y_min = None
                           )
            run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 8
p = 15
sigma1_squares = [2, 1, 0.5, 0.25, 0.1]
sigmas = [1] # 0.5, 1, 2
sigma = 1
misspecifications = [("cos", [2/4, 2/4]), ("cos", [3/4, 1/4])]
for misspecification in misspecifications:
    for order in ["concurrent", "episodic"]:
        for sigma1_square in sigma1_squares:
            if misspecification == ("cos", [2/4, 2/4]):
                if order == "episodic":
                    if sigma1_square in [2, 1]:
                        continue
                else:
                    continue
            reload(_experiment)
            run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                             , order = order
                                             , sigma1_square = sigma1_square
                                             , is_Binary = False
                                             , sigma = sigma
                                             , save_prefix = "mis_{}_{}_{}".format(misspecification[0], misspecification[1][0], misspecification[1][1])
                                             , print_SNR = True
                                             , misspecification = misspecification
                                            )
#             r = run.run_multiple_parallel(96)
            r = run.run_multiple_parallel(100, 2)
            run.plot_regret(ci = None
                            , plot_mean = True
                           , skip_methods = ["OSFA"]
                            , y_min = None
                           )
            run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 8
p = 15
sigma1_squares = [2, 1, 0.5, 0.25, 0.1]
sigmas = [1] # 0.5, 1, 2
sigma = 1
misspecifications = [("cos", [2/4, 2/4]), ("cos", [3/4, 1/4])]
for misspecification in misspecifications:
    for order in ["concurrent", "episodic"]:
        for sigma1_square in sigma1_squares:
            reload(_experiment)
            run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                             , order = order
                                             , sigma1_square = sigma1_square
                                             , is_Binary = False
                                             , sigma = sigma
                                             , save_prefix = "mis_{}_{}_{}".format(misspecification[0], misspecification[1][0], misspecification[1][1])
                                             , print_SNR = True
                                             , misspecification = misspecification
                                            )
            r = run.run_multiple_parallel(100, 2)
            run.plot_regret(ci = None
                            , plot_mean = True
                           , skip_methods = ["OSFA"]
                            , y_min = None
                           )
            run.save(sub_folder = ["N", "T", "K", "p", "sigma"])
