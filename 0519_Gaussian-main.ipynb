# %%
from _util import *
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"

import _experiment as _experiment
reload(_experiment)

# import shutil
# shutil.rmtree("res/0316") /
# shutil.rmtree("fig/0327")

# %%
N = 200
T = 200
K = 8
p = 15
# NT_pairs = [[30, 100]]
# Kp_pairs = [[5, 15], [3, 10]]
sigma1_squares = [1, 0.5, 0.25, 0.1]

sigma = 1
for order in ["concurrent"]:
    for sigma1_square in sigma1_squares:
        reload(_experiment)
        run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                         , order = order
                                         , sigma1_square = sigma1_square
                                         , is_Binary = False
                                         , sigma = sigma
                                         , save_prefix = "final_Gaussian"
                                         , Sigma_theta_factor = 1
                                         , print_SNR = True
                                         , Sigma_x_factor = 1
                                        )
        r = run.run_multiple_parallel(100, 2)
        run.plot_regret(ci = None
                        , plot_mean = True
                       , skip_methods = ["OSFA"]
                        , y_min = None
                       )
        run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 8
p = 15
# NT_pairs = [[30, 100]]
# Kp_pairs = [[5, 15], [3, 10]]
sigma1_squares = [1, 0.5, 0.25, 0.1]

sigma = 1
for order in ["concurrent", "episodic"]:
    for sigma1_square in sigma1_squares:
        reload(_experiment)
        run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                         , order = order
                                         , sigma1_square = sigma1_square
                                         , is_Binary = False
                                         , sigma = sigma
                                         , save_prefix = "final_Gaussian"
                                         , Sigma_theta_factor = 1
                                         , print_SNR = True
                                         , Sigma_x_factor = 1
                                        )
        r = run.run_multiple_parallel(100, 2)
        run.plot_regret(ci = None
                        , plot_mean = True
                       , skip_methods = ["OSFA"]
                        , y_min = None
                       )
        run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 2
p = 10
# NT_pairs = [[30, 100]]
# Kp_pairs = [[5, 15], [3, 10]]
sigma1_squares = [1, 0.5, 0.25, 0.1]

sigma = 1
for order in ["concurrent", "episodic"]:
    for sigma1_square in sigma1_squares:
        reload(_experiment)
        run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                         , order = order
                                         , sigma1_square = sigma1_square
                                         , is_Binary = False
                                         , sigma = sigma
                                         , save_prefix = "final_Gaussian"
                                         , Sigma_theta_factor = 1
                                         , print_SNR = True
                                         , Sigma_x_factor = 1
                                        )
        r = run.run_multiple_parallel(100, 2)
        run.plot_regret(ci = None
                        , plot_mean = True
                       , skip_methods = ["OSFA"]
                        , y_min = None
                       )
        run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 2
p = 10
# NT_pairs = [[30, 100]]
# Kp_pairs = [[5, 15], [3, 10]]
sigma1_squares = [1, 0.5, 0.25, 0.1]

sigma = 1
for order in ["concurrent", "episodic"]:
    for sigma1_square in sigma1_squares:
        reload(_experiment)
        run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                         , order = order
                                         , sigma1_square = sigma1_square
                                         , is_Binary = False
                                         , sigma = sigma
                                         , save_prefix = "final_Gaussian"
                                         , Sigma_theta_factor = 1
                                         , print_SNR = True
                                         , Sigma_x_factor = 1
                                        )
        r = run.run_multiple_parallel(100, 2)
        run.plot_regret(ci = None
                        , plot_mean = True
                       , skip_methods = ["OSFA"]
                        , y_min = None
                       )
        run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 8
p = 15
# NT_pairs = [[30, 100]]
# Kp_pairs = [[5, 15], [3, 10]]
sigma1_squares = [1, 0.5, 0.25, 0.1]

sigma = 1
for order in ["concurrent", "episodic"]:
    for sigma1_square in sigma1_squares:
        reload(_experiment)
        run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                         , order = order
                                         , sigma1_square = sigma1_square
                                         , is_Binary = False
                                         , sigma = sigma
                                         , save_prefix = "final_Gaussian"
                                         , Sigma_theta_factor = 1
                                         , print_SNR = True
                                         , Sigma_x_factor = 1
                                        )
        r = run.run_multiple_parallel(100, 2)
        # # r = run.run_one_seed_Binary(0)
#         run.plot_regret(ci = None
#                         , plot_mean = True
#                        , skip_methods = ["OSFA"]
#                         , y_min = None
#                        )
#         run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 8
p = 15
# NT_pairs = [[30, 100]]
# Kp_pairs = [[5, 15], [3, 10]]
sigma1_squares = [1, 0.5, 0.25, 0.1]

sigma = 1
for order in ["concurrent", "episodic"]:
    for sigma1_square in sigma1_squares:
        reload(_experiment)
        run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                         , order = order
                                         , sigma1_square = sigma1_square
                                         , is_Binary = False
                                         , sigma = sigma
                                         , save_prefix = "final_Gaussian"
                                         , Sigma_theta_factor = 1
                                         , print_SNR = True
                                         , Sigma_x_factor = 1
                                        )
        r = run.run_multiple_parallel(100, 2)
        # # r = run.run_one_seed_Binary(0)
        run.plot_regret(ci = None
                        , plot_mean = True
                       , skip_methods = ["OSFA"]
                        , y_min = None
                       )
        run.save(sub_folder = ["N", "T", "K", "p", "sigma"])

# %%
N = 200
T = 200
K = 8
p = 15
# NT_pairs = [[30, 100]]
# Kp_pairs = [[5, 15], [3, 10]]
sigma1_squares = [1, 0.5, 0.25, 0.1]

sigma = 1
for order in ["concurrent", "episodic"]:
    for sigma1_square in sigma1_squares:
        reload(_experiment)
        run = _experiment.run_experiment(N = N, T = T, K = K, p = p
                                         , order = order
                                         , sigma1_square = sigma1_square
                                         , is_Binary = False
                                         , sigma = sigma
                                         , save_prefix = "new_Gaussian"
                                         , Sigma_theta_factor = 1
                                         , print_SNR = True
                                         , Sigma_x_factor = 1
                                        )
        r = run.run_multiple_parallel(12)
        # # r = run.run_one_seed_Binary(0)
        run.plot_regret(ci = None
                        , plot_mean = True
                       , skip_methods = ["OSFA"]
                        , y_min = None
                       )
        run.save(sub_folder = ["N", "T", "K", "p", "sigma"]
                , only_plot_matrix = True)
